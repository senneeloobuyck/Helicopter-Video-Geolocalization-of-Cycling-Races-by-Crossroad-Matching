# %%
import cv2 
import os

# %%
course = "Ronde van Vlaanderen 1"
alias = "2023 RVV_1"
vid_path = "/Users/senneloobuyck/Documents/Thesis_project/01_inputs/videos/2023 Ronde van Vlaanderen 1.mp4"

# course = "Kuurne Brussel Kuurne"
# alias = "KBK"
# vid_path = "/Users/senneloobuyck/Documents/Thesis_project/01_inputs/videos/2020 KBK.mp4"

# %%
def get_yolo_demo_vid(video_path) :
    # Load the YOLOv8 model
    model = YOLO('best_v5.pt')

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Loop through the video frames
    while cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()

        if success:
            # Run YOLOv8 inference on the frame
            results = model.predict(frame, show=True, device="mps")

            # Visualize the results on the frame
            annotated_frame = results[0].plot()

            # Display the annotated frame
            cv2.imshow("YOLOv8 Inference", annotated_frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            # Break the loop if the end of the video is reached
            break

    # Release the video capture object and close the display window
    cap.release()
    cv2.destroyAllWindows()

# %%
get_yolo_demo_vid(vid_path)
# Out:
# Reading video frames of Ronde van Vlaanderen 1 to store in directory.
# Video has a fps of 25.0 frames per second.
# (512, 512, 3)
# Writing frame 2023 RVV_1_frame0.jpg, after 0.0 min and 0.0 seconds.
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# Writing frame 2023 RVV_1_frame25.jpg, after 0.0 min and 1.0 seconds.
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# ...
